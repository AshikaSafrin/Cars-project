# %% [markdown]
# # Final Model

# %%
from sklearn.tree import DecisionTreeRegressor
param_grid= {'criterion':['squared_error','friedman_mse','absolute_error','poisson'], 'splitter':['best','random']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(indep_X,dep_Y)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.027885      0.002634         0.015372        0.004226
# 1       0.018903      0.006147         0.006564        0.005332
# 2       0.007683      0.005020         0.010681        0.009038
# 3       0.017019      0.006709         0.003641        0.003719
# 4       0.025299      0.010145         0.010492        0.005795
# 5       0.026292      0.004104         0.007861        0.003475
# 6       0.018771      0.002269         0.008629        0.004590
# 7       0.020651      0.006671         0.006466        0.004933
#
#   param_criterion param_splitter  \
# 0   squared_error           best
# 1   squared_error         random
# 2    friedman_mse           best
# 3    friedman_mse         random
# 4  absolute_error           best
# 5  absolute_error         random
# 6         poisson           best
# 7         poisson         random
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'splitter': 'be...           0.600224
# 1  {'criterion': 'squared_error', 'splitter': 'ra...           0.307788
# 2  {'criterion': 'friedman_mse', 'splitter': 'best'}           0.408931
# 3  {'criterion': 'friedman_mse', 'splitter': 'ran...           0.392940
# 4  {'criterion': 'absolute_error', 'splitter': 'b...           0.623411
# 5  {'criterion': 'absolute_error', 'splitter': 'r...           0.132086
# 6       {'criterion': 'poisson', 'splitter': 'best'}           0.158071
# 7     {'criterion': 'poisson', 'splitter': 'random'}           0.287199
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.986758           1.000000           0.997498           1.000000
# 1           0.961956           1.000000           0.998332           0.999871
# 2           0.987073           0.995320           0.999166           0.999485
# 3           0.928325           1.000000           1.000000           1.000000
# 4           0.999790           0.994020           1.000000           1.000000
# 5           0.971729           1.000000           0.999583           1.000000
# 6           0.999054           0.999480           0.999166           1.000000
# 7           0.997793           0.988041           1.000000           0.999485
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.916896        0.158412                2
# 1         0.853589        0.273287                6
# 2         0.877995        0.234575                3
# 3         0.864253        0.237286                4
# 4         0.923444        0.150034                1
# 5         0.820680        0.344469                8
# 6         0.831154        0.336542                7
# 7         0.854504        0.283685                5
